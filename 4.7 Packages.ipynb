# %% [markdown]
# # Package

# %% [markdown]
# Packages are a way of structuring Python’s module namespace by using “dotted module names”.
#
# A directory must contain a file named init.py in order for Python to consider it as a package. This file can be left empty but we generally place the initialization code for that package in this file.

# %% [markdown]
# 1. group of modules are called packag
# 2. the example directory structure  of Game package available in notebook  clearly explaine with folder(package) and
# (sub packages) sub folders  every sub package contains __init__.py file and package also contain __init__.py for recognize it is package
# 3. python consider as any folders as modules

# %% [markdown]
# 4.  without __init__.py it could not consider as package
# 5. some times __init__.py keeps empyty some times it have intialize code
# 6. if __init__.py then python understands it is package

# %% [markdown]
# # importing module from a package

# %% [markdown]
# We can import modules from packages using the dot (.) operator

# %%
# import Game.Image.open     #here game is package image is subpackage  open is module name

# %%
#import  Game.sound.play   #here game is package sound  is subpackage  play is module name

# %% [markdown]
# # check out __init__.py is present in subpackage or not

# %% [markdown]
# import os
#
# exist = os.path.isfile('/path/to/subpackage/__init__.py')
#
# if exist:
#     print("something")
#
# else:
#     print("something")

# %% [markdown]
# # Library

# %% [markdown]
# 1. it contains multiple packages/modules or contains build in modules
# 2. simple term of bunch of code
# 3. use specific applications

# %% [markdown]
# # packages/modules

# %% [markdown]
# it is basically a directory with files

# %% [markdown]
# # To print out inside all functions in modules

# %% [markdown]
# import module
#
# help(module)
#
# will get all list of supported methods

# %% [markdown]
# dir(module)
#
# will get all related properties, methods of modules

# %%
import datetime

help(datetime)
# Out:
# Help on module datetime:
#
# NAME
#     datetime - Fast implementation of the datetime type.
#
# MODULE REFERENCE
#     https://docs.python.org/3.6/library/datetime
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# CLASSES
#     builtins.object
#         date
#             datetime
#         time
#         timedelta
#         tzinfo
#             timezone
#
#     class date(builtins.object)
#      |  date(year, month, day) --> date object
#      |
#      |  Methods defined here:
#      |
#      |  __add__(self, value, /)
#      |      Return self+value.
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __format__(...)
# ...

# %%
import datetime

dir(datetime)
# Out:
# ['MAXYEAR',
#  'MINYEAR',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'date',
#  'datetime',
#  'datetime_CAPI',
#  'sys',
#  'time',
#  'timedelta',
#  'timezone',
#  'tzinfo']

# %%
import numpy

# %%
help(numpy)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
dir(numpy)
# Out:
# ['ALLOW_THREADS',
#  'AxisError',
#  'BUFSIZE',
#  'CLIP',
#  'ComplexWarning',
#  'DataSource',
#  'ERR_CALL',
#  'ERR_DEFAULT',
#  'ERR_IGNORE',
#  'ERR_LOG',
#  'ERR_PRINT',
#  'ERR_RAISE',
#  'ERR_WARN',
#  'FLOATING_POINT_SUPPORT',
#  'FPE_DIVIDEBYZERO',
#  'FPE_INVALID',
#  'FPE_OVERFLOW',
#  'FPE_UNDERFLOW',
#  'False_',
#  'Inf',
#  'Infinity',
#  'MAXDIMS',
#  'MAY_SHARE_BOUNDS',
#  'MAY_SHARE_EXACT',
#  'MachAr',
#  'ModuleDeprecationWarning',
#  'NAN',
#  'NINF',
#  'NZERO',
#  'NaN',
#  'PINF',
#  'PZERO',
#  'PackageLoader',
#  'RAISE',
#  'RankWarning',
#  'SHIFT_DIVIDEBYZERO',
#  'SHIFT_INVALID',
#  'SHIFT_OVERFLOW',
#  'SHIFT_UNDERFLOW',
#  'ScalarType',
#  'Tester',
#  'TooHardError',
#  'True_',
#  'UFUNC_BUFSIZE_DEFAULT',
#  'UFUNC_PYVALS_NAME',
#  'VisibleDeprecationWarning',
#  'WRAP',
#  '_NoValue',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__doc__',
#  '__file__',
#  '__git_revision__',
#  '__loader__',
# ...
